# %% [markdown]
# <a href="https://colab.research.google.com/github/MarouaHY/yolo11/blob/main/ocr_and_wer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil

# Dossiers actuels
dataset_path = "/content/drive/MyDrive/ocr"
images_dir = os.path.join(dataset_path, "images")
annotations_dir = os.path.join(dataset_path, "annotations")

# Créer les dossiers s'ils n'existent pas
os.makedirs(images_dir, exist_ok=True)
os.makedirs(annotations_dir, exist_ok=True)

# Trier les fichiers
for file in os.listdir(dataset_path):
    file_path = os.path.join(dataset_path, file)

    if file.endswith(".jpg") or file.endswith(".png"):  # Images
        shutil.move(file_path, os.path.join(images_dir, file))
    elif file.endswith(".xml"):  # Annotations
        shutil.move(file_path, os.path.join(annotations_dir, file))

print("✅ Tri des fichiers terminé : images et annotations séparées !")
# Out:
# ✅ Tri des fichiers terminé : images et annotations séparées !

# %%
import os
import xml.etree.ElementTree as ET

# Paths
xml_dir = "/content/drive/MyDrive/ocr/annotations"
image_dir = "/content/drive/MyDrive/ocr/images"
ocr_labels_dir = "/content/drive/MyDrive/ocr/ocr labels dir"

# Create output folder
os.makedirs(ocr_labels_dir, exist_ok=True)

for xml_file in os.listdir(xml_dir):
    if xml_file.endswith(".xml"):
        xml_path = os.path.join(xml_dir, xml_file)
        tree = ET.parse(xml_path)
        root = tree.getroot()

        image_name = root.find("filename").text
        image_path = os.path.join(image_dir, image_name)
        ocr_annotation = image_path  # Start annotation with image path

        for obj in root.findall("object"):
            label = obj.find("name").text
            bbox = obj.find("bndbox")

            xmin = int(bbox.find("xmin").text)
            ymin = int(bbox.find("ymin").text)
            xmax = int(bbox.find("xmax").text)
            ymax = int(bbox.find("ymax").text)

            # Convert bounding box to four corner coordinates
            x1, y1 = xmin, ymin
            x2, y2 = xmax, ymin
            x3, y3 = xmax, ymax
            x4, y4 = xmin, ymax

            ocr_annotation += f" {x1},{y1},{x2},{y2},{x3},{y3},{x4},{y4},{label}"

        # Save OCR annotation
        ocr_label_path = os.path.join(ocr_labels_dir, xml_file.replace(".xml", ".txt"))
        with open(ocr_label_path, "w") as f:
            f.write(ocr_annotation + "\n")

print("✅ Conversion to OCR format completed!")
# Out:
# ✅ Conversion to OCR format completed!

# %%
import os

# Path to the folder containing OCR annotation text files
annotation_folder = "/content/drive/MyDrive/ocr/ocr labels dir"  # Change to your actual path
image_folder = "/content/drive/MyDrive/ocr/images"  # Change to your actual image folder
output_file = "/content/path/to/ocr_annotations/ocr_labels.txt"  # Output file

# Check if the annotation folder exists
if not os.path.isdir(annotation_folder):
    print(f"❌ Error: The path '{annotation_folder}' is not a valid directory!")
else:
    print(f"📁 Processing OCR annotations from: {annotation_folder}")

    # Open the output file for writing
    with open(output_file, "w") as outfile:
        # Iterate over all annotation files
        for filename in os.listdir(annotation_folder):
            file_path = os.path.join(annotation_folder, filename)

            # Process only text files
            if file_path.endswith(".txt") and os.path.isfile(file_path):
                try:
                    with open(file_path, "r") as infile:
                        parts = infile.readline().strip().split()

                        if len(parts) < 2:
                            print(f"⚠️ Skipping file (invalid annotation): {filename}")
                            continue

                        image_filename = parts[0]  # Image path
                        annotations = parts[1:]  # Annotations (bounding boxes + label)

                        # Extract only the characters (last column of each annotation)
                        license_plate_text = ""
                        for annotation in annotations:
                            coords = annotation.split(",")
                            if len(coords) == 9:
                                char_label = coords[8]  # Extract the character
                                license_plate_text += char_label

                        # Construct the full image path
                        image_path = os.path.join(image_folder, os.path.basename(image_filename))

                        # Write to the output file in the desired format
                        outfile.write(f"{image_path} {license_plate_text}\n")

                    print(f"✅ Processed: {filename} -> {license_plate_text}")

                except Exception as e:
                    print(f"❌ Error processing {filename}: {e}")

    print(f"✅ OCR labels saved to: {output_file}")
# Out:
# 📁 Processing OCR annotations from: /content/drive/MyDrive/ocr/ocr labels dir
# ✅ Processed: syn_1038_jpg.rf.37d156c0dd84769ef31c6afb936004c4.txt -> Z0VH5T9C
# ✅ Processed: syn_1135_jpg.rf.38bbaa07b8b7ab73b9374f7cb88fe479.txt -> 034NCSKUR
# ✅ Processed: syn_1057_jpg.rf.9deda12f7a3b84a3455740df6e172585.txt -> CBMBV53
# ✅ Processed: syn_1030_jpg.rf.869479638c5f632e588905cef32b4c35.txt -> 6D5RHXT
# ✅ Processed: syn_1026_jpg.rf.c6c6cc5255e4dbfb28bc7864ed014b27.txt -> 1V6GCKN0C
# ✅ Processed: syn_3122_jpg.rf.bebce8633815c3a99aa58612b8a45413.txt -> BT8KGGPVA
# ✅ Processed: syn_3086_jpg.rf.46b500efca8732b12794f36a2c468a0c.txt -> 2TASEUE2
# ✅ Processed: syn_3058_jpg.rf.78a1c7c2f61f2048a24de6299c9e847b.txt -> RXBKCKGY0
# ✅ Processed: syn_3375_jpg.rf.6ee6f815e6ce02db613f1e445621a019.txt -> D5V050N1S
# ✅ Processed: syn_3094_jpg.rf.c6fa69a6a57156edaf3d5796f465e6c3.txt -> U45CC83
# ✅ Processed: syn_3126_jpg.rf.3b23c247b93b0b4ee51f81fe41c52695.txt -> MMKHPG8DU
# ✅ Processed: syn_3182_jpg.rf.74f5a01dd44e99afc8099acae31601d3.txt -> 0Y9VZAE
# ✅ Processed: syn_3353_jpg.rf.6f0aef1e5e9fec81c9c7340a363e124c.txt -> S69ZG997
# ✅ Processed: syn_3163_jpg.rf.e70605cda70697a2e750efa8738cf1ac.txt -> 6DNZH6X
# ✅ Processed: syn_3139_jpg.rf.9addbfde0f361e547fc61124e87637e7.txt -> 3DHH3HBV
# ✅ Processed: syn_2863_jpg.rf.b6d7426da9c0671168515330d019d146.txt -> XGP9FD4RS
# ✅ Processed: syn_2837_jpg.rf.8023dadea424034ae6fa90871781b674.txt -> 59VEGFY0
# ✅ Processed: syn_3016_jpg.rf.7a3411742661d7e75d0cc91f8d35ede5.txt -> 6STV69S
# ✅ Processed: syn_2849_jpg.rf.6baae6749f66ed9fe1571799c28db2a3.txt -> 1SDZAG5Z
# ✅ Processed: syn_3046_jpg.rf.9ddb00893ea186fadcde8340bf726c13.txt -> NKS86299
# ✅ Processed: syn_2714_jpg.rf.5cdfbeb7bad366c2992901fef33bfbd9.txt -> X2PR2AV5
# ✅ Processed: syn_2806_jpg.rf.40dd98412f9d21f7f3939015c3204b67.txt -> RZYFVA8
# ✅ Processed: syn_25_jpg.rf.8f997604283dee3245d5ee46c8e80f37.txt -> H6R9ZRKSY
# ✅ Processed: syn_26_jpg.rf.517323d5e797e51f82a2959929cf032a.txt -> 99UPU1A0
# ✅ Processed: syn_2751_jpg.rf.dceb9e121cdd418f0fb39abf65357e80.txt -> 53F41CZV4
# ✅ Processed: syn_2704_jpg.rf.ef3bca2e9b0350fada279f6a2b0e92f4.txt -> ELN98MM
# ✅ Processed: syn_2682_jpg.rf.594319fca67a66b52aadfd35069ffb5e.txt -> 6UTH8XBL
# ✅ Processed: syn_2535_jpg.rf.e080c19d92aeab43486dc2e686defdc4.txt -> N4EGDRTC
# ✅ Processed: syn_2649_jpg.rf.cae5eab6a7cfa182f6957704af3eda2b.txt -> FZTDS2UK
# ✅ Processed: syn_2531_jpg.rf.c420a572bca60124b69af94175193f11.txt -> 1AT0N79
# ✅ Processed: syn_2403_jpg.rf.76f0d1bbddb3a1de3bb274c2ed7363e8.txt -> 9503349
# ✅ Processed: syn_2480_jpg.rf.71f649fb87ef0e949e2372b99131dc63.txt -> K4PEPBE9
# ✅ Processed: syn_2505_jpg.rf.0f4bd3d1129de0456dd99e27f89f4c86.txt -> PN0UDR6K
# ✅ Processed: syn_2497_jpg.rf.32e560220bc290d286a11ab619ec40a7.txt -> 87VN7ZTU4
# ✅ Processed: syn_2261_jpg.rf.dc445c38b2d99dc5c5cb5ee232c682fd.txt -> 1CC3009N
# ✅ Processed: syn_2382_jpg.rf.69ff198088a759bac92eaa8473432fa5.txt -> HEL7FVU
# ✅ Processed: syn_2175_jpg.rf.ecae694d1e69390d37c75a84b044f0bf.txt -> MZC2VEDP
# ✅ Processed: syn_2278_jpg.rf.72edb8bdd7ed88d87ee098a4f07a1972.txt -> 0YN2V7LM
# ✅ Processed: syn_2521_jpg.rf.1db664171fbb11a7f91373fe0effd0fe.txt -> 7ED1B9S
# ✅ Processed: syn_2167_jpg.rf.2ec7ae84a57e3eaa15f80b554051e7c0.txt -> LL341RY
# ✅ Processed: syn_2385_jpg.rf.afdaadd903d3e89d57f888d2eee31f6a.txt -> DER5F0HL
# ✅ Processed: syn_2040_jpg.rf.b4e6484da879cfa57a92f4dfa2fa6608.txt -> 6EG2R6VE
# ✅ Processed: syn_2149_jpg.rf.8ca0f19d7c836d1de9536cbfde803b41.txt -> 1KNKP5536
# ✅ Processed: syn_189_jpg.rf.289b9fdcbe2813df88e566d9504055b5.txt -> SFEP4BCZ
# ✅ Processed: syn_2014_jpg.rf.c8bc50a432e935b71e8951fd94c6d4d4.txt -> 3CHPUP2
# ✅ Processed: syn_1854_jpg.rf.cf07cfd8aa397c5f4fd1b3b080152200.txt -> DZUX561N
# ✅ Processed: syn_1762_jpg.rf.cea7b8224cbccd016719da33a2e5f45e.txt -> 4MR0CFFX
# ✅ Processed: syn_1683_jpg.rf.8ea304c03c63047cf0cea8b95b0982c6.txt -> CLE5CD0D2
# ✅ Processed: syn_1620_jpg.rf.c3f68f6e02b449ee748562af56fe46fe.txt -> 7XRX443K
# ✅ Processed: syn_1581_jpg.rf.7f95869ae0b2d0e308fcc737e234f4a3.txt -> MHRH48R
# ✅ Processed: syn_1428_jpg.rf.78c450f33b6df54bb86dda3abadc14ce.txt -> YGCMZKSH
# ✅ Processed: syn_1535_jpg.rf.1ec9f1d1ae5e5ecc68e57203f5783070.txt -> THSUVNZ3
# ✅ Processed: syn_139_jpg.rf.6dd5d79d7ee71a237bf10398585a7873.txt -> 1VH809R5
# ✅ Processed: syn_1432_jpg.rf.97756cee83b68783bdc50ce20830f7f0.txt -> L0X7U8G
# ✅ Processed: syn_1426_jpg.rf.1aae7ddc03449c2b027f6cf0823234a9.txt -> 7AYZF3KGN
# ✅ Processed: syn_1208_jpg.rf.0a9618e5a7808be8ad386f62ef32168a.txt -> ZM9HRS6
# ✅ Processed: syn_1178_jpg.rf.ada991ca56896853410638188f7c42c9.txt -> BAPDPGN7C
# ✅ Processed: syn_1297_jpg.rf.affb60a097002b89f2812d62ff0568fa.txt -> 938P41P
# ✅ Processed: syn_1295_jpg.rf.360de86b425869e0db83efdadbbaa380.txt -> KVT2HL9
# ✅ Processed: syn_1303_jpg.rf.3187079e6a0efd869f294e60d539803c.txt -> TB722Y2UD
# ✅ Processed: syn_53_jpg.rf.a3e33624594acc249ed1a98e4ef240bc.txt -> AAL15V47
# ✅ Processed: syn_543_jpg.rf.9ca32b75d1685d35ecd8e1646ff6bc3f.txt -> CAYSD2GV
# ✅ Processed: syn_513_jpg.rf.621a1322ce77de2b0a615f5026776a75.txt -> 8P8YD6K9
# ✅ Processed: syn_527_jpg.rf.7a106886a148ed3d8e66b5a8eeab80bc.txt -> C4U82GM8
# ✅ Processed: syn_544_jpg.rf.35cca203ad13e9dfa11c0d24783a0b7a.txt -> 2HFX7NB6H
# ✅ Processed: syn_4738_jpg.rf.3cc72e86ffc8c556bf1e3cfc1fcb45eb.txt -> 88LSAC4
# ✅ Processed: syn_4718_jpg.rf.7f041829b6a602a2ddc8cd6408acb250.txt -> UZAAZH6Y
# ✅ Processed: syn_4812_jpg.rf.d74cde9c7c9c443218adb8ba3f738090.txt -> 7EH01EE
# ✅ Processed: syn_4769_jpg.rf.e622ed005f4e84e3ef2bbe86f4a725cb.txt -> PZ7CB9X
# ✅ Processed: syn_4881_jpg.rf.60d5da1a7f6e255ac4e322638a92bb05.txt -> NLPM59TC
# ✅ Processed: syn_4685_jpg.rf.17bc1551a7303280b77df712ea6bb4b1.txt -> ELPUXHY
# ✅ Processed: syn_461_jpg.rf.e956501373d7c1d12c0b2fd1955f42ed.txt -> USRAA2X1
# ✅ Processed: syn_4429_jpg.rf.44fd9b4d7e655a4c4139975be9f8a5eb.txt -> GEV8NHE
# ✅ Processed: syn_4654_jpg.rf.2428cf17bc43245cbcf760d4a3bb2062.txt -> AM9PZDM5X
# ✅ Processed: syn_4559_jpg.rf.f5620129cc67cfa683785562c8b9f18c.txt -> 7DCP7AK
# ✅ Processed: syn_4409_jpg.rf.fb5dcc8c0c43424275d0c768fbb62ef7.txt -> YAMH834L
# ✅ Processed: syn_4214_jpg.rf.9263d6141a57ccdcc9d20f902f6a99b6.txt -> 1P45LU8
# ✅ Processed: syn_4175_jpg.rf.f6c5caf8acf32f314ad7b18c1c0001e5.txt -> Y7PUZGEU
# ✅ Processed: syn_4167_jpg.rf.fd2c743d262d5c786b669a10da6e6762.txt -> 9YCX8SFA
# ✅ Processed: syn_4226_jpg.rf.9d3ac615f6e55ae9a252cab4ef7151c1.txt -> 4744T8K8
# ✅ Processed: syn_3726_jpg.rf.278b13b4872ea5382f9c0eb9e373c5db.txt -> 2TCMREAZA
# ✅ Processed: syn_3464_jpg.rf.e8f5ed6c3fedda6051a4be75430c6d34.txt -> XM7BHB3B
# ✅ Processed: syn_4149_jpg.rf.a9e11d566a24df87f6478ef27f10e319.txt -> HB3BFRR1
# ✅ Processed: syn_3885_jpg.rf.138f185f7b73980956ad8258ea80934d.txt -> N6PE624
# ✅ Processed: syn_4040_jpg.rf.cb06566c941f731db62ed0a9f5b472e1.txt -> TDP4R3CL
# ✅ Processed: syn_3880_jpg.rf.be612e28a3da67120f19105849ecfbe3.txt -> YU61S3R4
# ✅ Processed: syn_4130_jpg.rf.f97e2f4f620dcc1563a8b7a2f0d45841.txt -> 9VVPU95
# ✅ Processed: syn_4062_jpg.rf.e5ebfee9ef1b5a8c20ac26d9fa6e2daa.txt -> NYK252X47
# ✅ Processed: syn_3856_jpg.rf.c43342a8ae470ae1751e73e65fdc55be.txt -> EXDEKM8G
# ✅ Processed: syn_3783_jpg.rf.fa8aad0142f844e58de5bf827edd594c.txt -> RSC0DRT72
# ✅ Processed: syn_821_jpg.rf.3554ef0e1545cea0409c061e9e71c9e5.txt -> HMEM54M4L
# ✅ Processed: syn_709_jpg.rf.a694f46cc2d530cc10bb52d32f1175df.txt -> RRVSFNA5
# ✅ Processed: syn_780_jpg.rf.e62fc0e6c14838c325e02631cee7ef87.txt -> BL8H93K5
# ✅ Processed: syn_70_jpg.rf.7b0fbb82f43ef0df53548d479a5008c8.txt -> 0AZ4LB7RY
# ✅ Processed: syn_703_jpg.rf.90bad0692ab8f69da9695e0a3d96b586.txt -> 5N4D51N
# ✅ Processed: syn_980_jpg.rf.e8f369780768d726beca1bb617b22e98.txt -> E4SZ4PGY
# ✅ Processed: TestImage_png.rf.2b70bc1d3b480b3aea8fac65367c1ddf.txt -> 6354JLX
# ✅ Processed: syn_879_jpg.rf.6ba72002872db6a44cf77f066e08cd5e.txt -> RLVBDUEM
# ✅ Processed: syn_856_jpg.rf.5441c699e974c4a4f116b790227d865b.txt -> ANPALADM0
# ✅ Processed: syn_747_jpg.rf.a68f1065f1fbf624967f004790aaf036.txt -> 8Z9GN17P
# ✅ Processed: syn_663_jpg.rf.c17d3faefa30fe81a43fd6be4d226873.txt -> ALPS7E7Z
# ✅ Processed: syn_54_jpg.rf.2a59fff2bb068455dc276d29d52e8f8b.txt -> FELKA1U
# ✅ Processed: syn_59_jpg.rf.3d6a2e581114fd3d0c222329bf24e62a.txt -> 5VEE68XG
# ✅ Processed: syn_632_jpg.rf.7f604c0552fd53f8c8f71e8f3d95aa54.txt -> 6HHKU65T
# ✅ OCR labels saved to: /content/path/to/ocr_annotations/ocr_labels.txt

# %% [markdown]
# # Partie Paddle

# %%
# !pip install paddlepaddle paddleocr
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp311-cp311-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting paddleocr
#   Downloading paddleocr-2.9.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from paddlepaddle) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from paddlepaddle) (11.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from paddlepaddle) (4.4.2)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle) (4.25.6)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.0.7)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.25.2)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.11/dist-packages (from paddleocr) (0.4.0)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.67.1)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.11.0.86)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.11.0.86)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from paddleocr) (3.0.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.13.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.11/dist-packages (from paddleocr) (4.56.0)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from paddleocr) (2.32.3)
# Collecting albumentations==1.4.10 (from paddleocr)
#   Downloading albumentations-1.4.10-py3-none-any.whl.metadata (38 kB)
# Collecting albucore==0.0.13 (from paddleocr)
#   Downloading albucore-0.0.13-py3-none-any.whl.metadata (3.1 kB)
# Collecting tomli>=2.0.1 (from albucore==0.0.13->paddleocr)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.13->paddleocr) (4.12.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.13->paddleocr) (4.10.0.84)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.10->paddleocr) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.10->paddleocr) (1.6.1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from albumentations==1.4.10->paddleocr) (2.10.6)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.3.0->paddleocr) (2.5.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (2025.2.18)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from imgaug->paddleocr) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from imgaug->paddleocr) (3.10.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx->paddleocr) (5.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->paddleocr) (2.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations==1.4.10->paddleocr) (2.27.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.10->paddleocr) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Downloading paddlepaddle-2.6.2-cp311-cp311-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 4.5 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.9 MB/s eta 0:00:00
# Downloading paddleocr-2.9.1-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 24.6 MB/s eta 0:00:00
# Downloading albucore-0.0.13-py3-none-any.whl (8.5 kB)
# Downloading albumentations-1.4.10-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 10.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 21.0 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 48.0 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 16.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.5 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 16.5 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=52df7bafd7b94af92fb8c9f859ebc10ab4ca65624bc6ff0799fd5f130f7323a2
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, tomli, rapidfuzz, python-docx, opt-einsum, fire, astor, albucore, paddlepaddle, albumentations, paddleocr
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.23
#     Uninstalling albucore-0.0.23:
#       Successfully uninstalled albucore-0.0.23
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 2.0.4
#     Uninstalling albumentations-2.0.4:
#       Successfully uninstalled albumentations-2.0.4
# Successfully installed albucore-0.0.13 albumentations-1.4.10 astor-0.8.1 fire-0.7.0 lmdb-1.6.2 opt-einsum-3.3.0 paddleocr-2.9.1 paddlepaddle-2.6.2 pyclipper-1.3.0.post6 python-docx-1.1.2 rapidfuzz-3.12.1 tomli-2.2.1

# %%
from paddleocr import PaddleOCR
print("Importation réussie ✅")
# Out:
# Importation réussie ✅

# %% [markdown]
# # Tester paddle sur tout le dataset

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.26.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.26.1 (from python-Levenshtein)
#   Downloading levenshtein-0.26.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from Levenshtein==0.26.1->python-Levenshtein) (3.12.1)
# Downloading python_Levenshtein-0.26.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.26.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.26.1 python-Levenshtein-0.26.1

# %% [markdown]
# # Evaluer avec l'OCR avec WER

# %%
import os
import re
import paddleocr
import Levenshtein

# Charger PaddleOCR
ocr = paddleocr.PaddleOCR(use_angle_cls=True, lang='en')

# Charger le fichier des Ground Truths
gt_file_path = "/content/path/to/ocr_annotations/ocr_labels.txt"
ground_truths = {}

# Lecture et extraction des Ground Truths
with open(gt_file_path, "r", encoding="utf-8") as f:
    for line in f:
        parts = line.strip().split()  # Séparation par espace (évite problème de tabulation)
        if len(parts) >= 2:
            image_path, plate_text = parts[0], parts[1]
            image_name = os.path.basename(image_path)  # Extraire uniquement le nom du fichier
            ground_truths[image_name] = plate_text.replace(" ", "")  # Enlever les espaces

# Vérification des Ground Truths chargés
print("✅ Exemple de correspondance GT :")
for i, (k, v) in enumerate(ground_truths.items()):
    if i < 5:
        print(f"{k} -> {v}")

# Fonction pour extraire uniquement le texte de la plaque
def extract_plate_text(ocr_result):
    if ocr_result is None:
        return ""  # Éviter l'erreur TypeError si rien n'est détecté

    extracted_text = []
    for res in ocr_result:
        text = res[1][0].upper()  # Récupérer le texte OCR et mettre en majuscules
        clean_text = re.sub(r"[^A-Z0-9]", "", text)  # Garder uniquement lettres & chiffres
        extracted_text.append(clean_text)

    return "".join(extracted_text)  # Concaténer tous les morceaux

# Dossier contenant les images
image_folder = "/content/drive/MyDrive/ocr/images"
wer_scores = []  # Liste pour stocker les WER de chaque image

# Traitement de chaque image
for image_name in os.listdir(image_folder):
    image_path = os.path.join(image_folder, image_name)

    # Exécuter l'OCR
    ocr_result = ocr.ocr(image_path, cls=True)
    extracted_plate = extract_plate_text(ocr_result[0] if ocr_result else None)

    # Récupérer le Ground Truth correspondant
    ground_truth = ground_truths.get(image_name, "N/A")

    # Calculer le WER (si le GT n'est pas "N/A")
    if ground_truth != "N/A":
        wer = Levenshtein.distance(ground_truth, extracted_plate) / max(len(ground_truth), 1)
        wer_scores.append(wer)
    else:
        wer = None

    # Affichage des résultats
    print(f"🖼 Image: {image_name}")
    print(f"✅ Ground Truth: {ground_truth}")
    print(f"🔍 OCR Result: {extracted_plate}")
    print(f"⚡ WER: {wer:.4f}" if wer is not None else "⚠️ WER: N/A (pas de GT disponible)")
    print("-" * 50)

# Calcul du WER moyen
if wer_scores:
    wer_mean = sum(wer_scores) / len(wer_scores)
    print("\n📊 WER Moyen sur toutes les images :", round(wer_mean, 4))
else:
    print("\n⚠️ Impossible de calculer le WER moyen (aucun GT valide).")
# Out:
# [2025/02/24 20:15:43] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.11/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# ✅ Exemple de correspondance GT :
# syn_1038_jpg.rf.37d156c0dd84769ef31c6afb936004c4.jpg -> Z0VH5T9C
# syn_1135_jpg.rf.38bbaa07b8b7ab73b9374f7cb88fe479.jpg -> 034NCSKUR
# syn_1057_jpg.rf.9deda12f7a3b84a3455740df6e172585.jpg -> CBMBV53
# syn_1030_jpg.rf.869479638c5f632e588905cef32b4c35.jpg -> 6D5RHXT
# syn_1026_jpg.rf.c6c6cc5255e4dbfb28bc7864ed014b27.jpg -> 1V6GCKN0C
# [2025/02/24 20:15:46] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.26595282554626465
# [2025/02/24 20:15:46] ppocr DEBUG: cls num  : 2, elapsed : 0.021146297454833984
# [2025/02/24 20:15:46] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16247987747192383
# 🖼 Image: syn_1208_jpg.rf.0a9618e5a7808be8ad386f62ef32168a.jpg
# ✅ Ground Truth: ZM9HRS6
# 🔍 OCR Result: ZM9HRS6
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:15:48] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.42359495162963867
# [2025/02/24 20:15:48] ppocr DEBUG: cls num  : 2, elapsed : 0.01973748207092285
# [2025/02/24 20:15:48] ppocr DEBUG: rec_res num  : 2, elapsed : 0.14188599586486816
# 🖼 Image: syn_1135_jpg.rf.38bbaa07b8b7ab73b9374f7cb88fe479.jpg
# ✅ Ground Truth: 034NCSKUR
# 🔍 OCR Result: 270CSKUR
# ⚡ WER: 0.4444
# --------------------------------------------------
# [2025/02/24 20:15:48] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.20704889297485352
# [2025/02/24 20:15:48] ppocr DEBUG: cls num  : 2, elapsed : 0.01875925064086914
# [2025/02/24 20:15:48] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1396942138671875
# 🖼 Image: syn_1057_jpg.rf.9deda12f7a3b84a3455740df6e172585.jpg
# ✅ Ground Truth: CBMBV53
# 🔍 OCR Result: CBMBV53
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:15:48] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1420271396636963
# [2025/02/24 20:15:48] ppocr DEBUG: cls num  : 2, elapsed : 0.010569334030151367
# [2025/02/24 20:15:48] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09312796592712402
# 🖼 Image: syn_1026_jpg.rf.c6c6cc5255e4dbfb28bc7864ed014b27.jpg
# ✅ Ground Truth: 1V6GCKN0C
# 🔍 OCR Result: 1V6GCKNOC
# ⚡ WER: 0.1111
# --------------------------------------------------
# [2025/02/24 20:15:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.18395042419433594
# [2025/02/24 20:15:49] ppocr DEBUG: cls num  : 2, elapsed : 0.015474319458007812
# [2025/02/24 20:15:49] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1231999397277832
# 🖼 Image: syn_1038_jpg.rf.37d156c0dd84769ef31c6afb936004c4.jpg
# ✅ Ground Truth: Z0VH5T9C
# 🔍 OCR Result: HAOZ5T9C
# ⚡ WER: 0.5000
# --------------------------------------------------
# [2025/02/24 20:15:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.
05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10187220573425293
# 🖼 Image: syn_543_jpg.rf.9ca32b75d1685d35ecd8e1646ff6bc3f.jpg
# ✅ Ground Truth: CAYSD2GV
# 🔍 OCR Result: CAYSD2GV
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:05] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1491246223449707
# [2025/02/24 20:16:05] ppocr DEBUG: cls num  : 2, elapsed : 0.009903907775878906
# [2025/02/24 20:16:05] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0872659683227539
# 🖼 Image: syn_59_jpg.rf.3d6a2e581114fd3d0c222329bf24e62a.jpg
# ✅ Ground Truth: 5VEE68XG
# 🔍 OCR Result: 5VEE68XG
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14760994911193848
# [2025/02/24 20:16:06] ppocr DEBUG: cls num  : 2, elapsed : 0.010109901428222656
# [2025/02/24 20:16:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0927114486694336
# 🖼 Image: syn_527_jpg.rf.7a106886a148ed3d8e66b5a8eeab80bc.jpg
# ✅ Ground Truth: C4U82GM8
# 🔍 OCR Result: C7U82GM8
# ⚡ WER: 0.1250
# --------------------------------------------------
# [2025/02/24 20:16:06] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.13388872146606445
# [2025/02/24 20:16:06] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:06] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# 🖼 Image: syn_53_jpg.rf.a3e33624594acc249ed1a98e4ef240bc.jpg
# ✅ Ground Truth: AAL15V47
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14066243171691895
# [2025/02/24 20:16:06] ppocr DEBUG: cls num  : 2, elapsed : 0.010364532470703125
# [2025/02/24 20:16:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08766984939575195
# 🖼 Image: syn_513_jpg.rf.621a1322ce77de2b0a615f5026776a75.jpg
# ✅ Ground Truth: 8P8YD6K9
# 🔍 OCR Result: 8P8YD6K9
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:06] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.16955804824829102
# [2025/02/24 20:16:06] ppocr DEBUG: cls num  : 2, elapsed : 0.010237693786621094
# [2025/02/24 20:16:06] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0872042179107666
# 🖼 Image: syn_4769_jpg.rf.e622ed005f4e84e3ef2bbe86f4a725cb.jpg
# ✅ Ground Truth: PZ7CB9X
# 🔍 OCR Result: PZ7CB9X
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:07] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.14908933639526367
# [2025/02/24 20:16:07] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:07] ppocr DEBUG: rec_res num  : 0, elapsed : 2.6226043701171875e-06
# 🖼 Image: syn_4718_jpg.rf.7f041829b6a602a2ddc8cd6408acb250.jpg
# ✅ Ground Truth: UZAAZH6Y
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13767743110656738
# [2025/02/24 20:16:07] ppocr DEBUG: cls num  : 2, elapsed : 0.009797811508178711
# [2025/02/24 20:16:07] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0887444019317627
# 🖼 Image: syn_4881_jpg.rf.60d5da1a7f6e255ac4e322638a92bb05.jpg
# ✅ Ground Truth: NLPM59TC
# 🔍 OCR Result: NLPM59TC
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14206886291503906
# [2025/02/24 20:16:07] ppocr DEBUG: cls num  : 2, elapsed : 0.010455131530761719
# [2025/02/24 20:16:07] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09307026863098145
# 🖼 Image: syn_4812_jpg.rf.d74cde9c7c9c443218adb8ba3f738090.jpg
# ✅ Ground Truth: 7EH01EE
# 🔍 OCR Result: 7EH01EE
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13900208473205566
# [2025/02/24 20:16:07] ppocr DEBUG: cls num  : 2, elapsed : 0.011164665222167969
# [2025/02/24 20:16:07] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10179829597473145
# 🖼 Image: syn_4738_jpg.rf.3cc72e86ffc8c556bf1e3cfc1fcb45eb.jpg
# ✅ Ground Truth: 88LSAC4
# 🔍 OCR Result: 88LSAC4
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:07] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14501094818115234
# [2025/02/24 20:16:08] ppocr DEBUG: cls num  : 2, elapsed : 0.010190725326538086
# [2025/02/24 20:16:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09537220001220703
# 🖼 Image: syn_4654_jpg.rf.2428cf17bc43245cbcf760d4a3bb2062.jpg
# ✅ Ground Truth: AM9PZDM5X
# 🔍 OCR Result: AM9PZDM5X
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13597917556762695
# [2025/02/24 20:16:08] ppocr DEBUG: cls num  : 2, elapsed : 0.010275840759277344
# [2025/02/24 20:16:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09209775924682617
# 🖼 Image: syn_4685_jpg.rf.17bc1551a7303280b77df712ea6bb4b1.jpg
# ✅ Ground Truth: ELPUXHY
# 🔍 OCR Result: ELPUXHY
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:08] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.1380302906036377
# [2025/02/24 20:16:08] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:08] ppocr DEBUG: rec_res num  : 0, elapsed : 2.1457672119140625e-06
# 🖼 Image: syn_4429_jpg.rf.44fd9b4d7e655a4c4139975be9f8a5eb.jpg
# ✅ Ground Truth: GEV8NHE
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13801050186157227
# [2025/02/24 20:16:08] ppocr DEBUG: cls num  : 2, elapsed : 0.009859085083007812
# [2025/02/24 20:16:08] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10295772552490234
# 🖼 Image: syn_461_jpg.rf.e956501373d7c1d12c0b2fd1955f42ed.jpg
# ✅ Ground Truth: USRAA2X1
# 🔍 OCR Result: USRAA2X1
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:08] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14481091499328613
# [2025/02/24 20:16:08] ppocr DEBUG: cls num  : 2, elapsed : 0.010680913925170898
# [2025/02/24 20:16:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.10324215888977051
# 🖼 Image: syn_4409_jpg.rf.fb5dcc8c0c43424275d0c768fbb62ef7.jpg
# ✅ Ground Truth: YAMH834L
# 🔍 OCR Result: YAMH834L
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:09] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.15839076042175293
# [2025/02/24 20:16:09] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:09] ppocr DEBUG: rec_res num  : 0, elapsed : 2.1457672119140625e-06
# 🖼 Image: syn_4559_jpg.rf.f5620129cc67cfa683785562c8b9f18c.jpg
# ✅ Ground Truth: 7DCP7AK
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:09] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1396477222442627
# [2025/02/24 20:16:09] ppocr DEBUG: cls num  : 2, elapsed : 0.01222681999206543
# [2025/02/24 20:16:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0882110595703125
# 🖼 Image: syn_4175_jpg.rf.f6c5caf8acf32f314ad7b18c1c0001e5.jpg
# ✅ Ground Truth: Y7PUZGEU
# 🔍 OCR Result: Y7PUZGEU
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:09] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13833236694335938
# [2025/02/24 20:16:09] ppocr DEBUG: cls num  : 2, elapsed : 0.010091304779052734
# [2025/02/24 20:16:09] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08837699890136719
# 🖼 Image: syn_4167_jpg.rf.fd2c743d262d5c786b669a10da6e6762.jpg
# ✅ Ground Truth: 9YCX8SFA
# 🔍 OCR Result: 9YCX8SFA
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:09] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.15158414840698242
# [2025/02/24 20:16:09] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:09] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# 🖼 Image: syn_4226_jpg.rf.9d3ac615f6e55ae9a252cab4ef7151c1.jpg
# ✅ Ground Truth: 4744T8K8
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1421818733215332
# [2025/02/24 20:16:10] ppocr DEBUG: cls num  : 2, elapsed : 0.010386228561401367
# [2025/02/24 20:16:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09860062599182129
# 🖼 Image: syn_4214_jpg.rf.9263d6141a57ccdcc9d20f902f6a99b6.jpg
# ✅ Ground Truth: 1P45LU8
# 🔍 OCR Result: 1P45LU8
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1383650302886963
# [2025/02/24 20:16:10] ppocr DEBUG: cls num  : 2, elapsed : 0.011400938034057617
# [2025/02/24 20:16:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08944344520568848
# 🖼 Image: syn_3464_jpg.rf.e8f5ed6c3fedda6051a4be75430c6d34.jpg
# ✅ Ground Truth: XM7BHB3B
# 🔍 OCR Result: XM7BHB3B
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:10] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13580083847045898
# [2025/02/24 20:16:10] ppocr DEBUG: cls num  : 2, elapsed : 0.01347494125366211
# [2025/02/24 20:16:10] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09358358383178711
# 🖼 Image: syn_3783_jpg.rf.fa8aad0142f844e58de5bf827edd594c.jpg
# ✅ Ground Truth: RSC0DRT72
# 🔍 OCR Result: RSCODRT72
# ⚡ WER: 0.1111
# --------------------------------------------------
# [2025/02/24 20:16:10] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.153181791305542
# [2025/02/24 20:16:10] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:10] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# 🖼 Image: syn_3856_jpg.rf.c43342a8ae470ae1751e73e65fdc55be.jpg
# ✅ Ground Truth: EXDEKM8G
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:11] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14764094352722168
# [2025/02/24 20:16:11] ppocr DEBUG: cls num  : 2, elapsed : 0.013580560684204102
# [2025/02/24 20:16:11] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09314465522766113
# 🖼 Image: syn_4062_jpg.rf.e5ebfee9ef1b5a8c20ac26d9fa6e2daa.jpg
# ✅ Ground Truth: NYK252X47
# 🔍 OCR Result: NYK252X47
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:11] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.13303136825561523
# [2025/02/24 20:16:11] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:11] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# 🖼 Image: syn_3885_jpg.rf.138f185f7b73980956ad8258ea80934d.jpg
# ✅ Ground Truth: N6PE624
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:11] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13959503173828125
# [2025/02/24 20:16:11] ppocr DEBUG: cls num  : 2, elapsed : 0.010201454162597656
# [2025/02/24 20:16:11] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08893346786499023
# 🖼 Image: syn_4040_jpg.rf.cb06566c941f731db62ed0a9f5b472e1.jpg
# ✅ Ground Truth: TDP4R3CL
# 🔍 OCR Result: TOP4R3CL
# ⚡ WER: 0.1250
# --------------------------------------------------
# [2025/02/24 20:16:11] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.13532662391662598
# [2025/02/24 20:16:11] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:11] ppocr DEBUG: rec_res num  : 0, elapsed : 1.9073486328125e-06
# 🖼 Image: syn_4149_jpg.rf.a9e11d566a24df87f6478ef27f10e319.jpg
# ✅ Ground Truth: HB3BFRR1
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:11] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.15580487251281738
# [2025/02/24 20:16:11] ppocr DEBUG: cls num  : 2, elapsed : 0.01051640510559082
# [2025/02/24 20:16:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.0940861701965332
# 🖼 Image: syn_4130_jpg.rf.f97e2f4f620dcc1563a8b7a2f0d45841.jpg
# ✅ Ground Truth: 9VVPU95
# 🔍 OCR Result: 9VVPU95
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13567757606506348
# [2025/02/24 20:16:12] ppocr DEBUG: cls num  : 2, elapsed : 0.01091623306274414
# [2025/02/24 20:16:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08900213241577148
# 🖼 Image: syn_3880_jpg.rf.be612e28a3da67120f19105849ecfbe3.jpg
# ✅ Ground Truth: YU61S3R4
# 🔍 OCR Result: YU61S3R4
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.14171600341796875
# [2025/02/24 20:16:12] ppocr DEBUG: cls num  : 2, elapsed : 0.010016441345214844
# [2025/02/24 20:16:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.08922481536865234
# 🖼 Image: syn_3726_jpg.rf.278b13b4872ea5382f9c0eb9e373c5db.jpg
# ✅ Ground Truth: 2TCMREAZA
# 🔍 OCR Result: 2TCMREAZA
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.13581323623657227
# [2025/02/24 20:16:12] ppocr DEBUG: cls num  : 2, elapsed : 0.010076522827148438
# [2025/02/24 20:16:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09015965461730957
# 🖼 Image: syn_709_jpg.rf.a694f46cc2d530cc10bb52d32f1175df.jpg
# ✅ Ground Truth: RRVSFNA5
# 🔍 OCR Result: RRVSFNA5
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:13] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.15868234634399414
# [2025/02/24 20:16:13] ppocr DEBUG: cls num  : 2, elapsed : 0.011169910430908203
# [2025/02/24 20:16:13] ppocr DEBUG: rec_res num  : 2, elapsed : 0.09044480323791504
# 🖼 Image: syn_747_jpg.rf.a68f1065f1fbf624967f004790aaf036.jpg
# ✅ Ground Truth: 8Z9GN17P
# 🔍 OCR Result: 879GN17P
# ⚡ WER: 0.1250
# --------------------------------------------------
# [2025/02/24 20:16:13] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.176954984664917
# [2025/02/24 20:16:13] ppocr DEBUG: cls num  : 2, elapsed : 0.01444554328918457
# [2025/02/24 20:16:13] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1395564079284668
# 🖼 Image: syn_70_jpg.rf.7b0fbb82f43ef0df53548d479a5008c8.jpg
# ✅ Ground Truth: 0AZ4LB7RY
# 🔍 OCR Result: OAZ4LB7RY
# ⚡ WER: 0.1111
# --------------------------------------------------
# [2025/02/24 20:16:13] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.1978912353515625
# [2025/02/24 20:16:13] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:13] ppocr DEBUG: rec_res num  : 0, elapsed : 1.9073486328125e-06
# 🖼 Image: TestImage_png.rf.2b70bc1d3b480b3aea8fac65367c1ddf.jpg
# ✅ Ground Truth: 6354JLX
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:13] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.20562481880187988
# [2025/02/24 20:16:13] ppocr DEBUG: cls num  : 2, elapsed : 0.015496015548706055
# [2025/02/24 20:16:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13084793090820312
# 🖼 Image: syn_980_jpg.rf.e8f369780768d726beca1bb617b22e98.jpg
# ✅ Ground Truth: E4SZ4PGY
# 🔍 OCR Result: E4SZ4PGY
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.1976923942565918
# [2025/02/24 20:16:14] ppocr DEBUG: cls num  : 2, elapsed : 0.013031244277954102
# [2025/02/24 20:16:14] ppocr DEBUG: rec_res num  : 2, elapsed : 0.1363677978515625
# 🖼 Image: syn_856_jpg.rf.5441c699e974c4a4f116b790227d865b.jpg
# ✅ Ground Truth: ANPALADM0
# 🔍 OCR Result: ANPALADMO
# ⚡ WER: 0.1111
# --------------------------------------------------
# [2025/02/24 20:16:14] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.1893470287322998
# [2025/02/24 20:16:14] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:14] ppocr DEBUG: rec_res num  : 0, elapsed : 2.1457672119140625e-06
# 🖼 Image: syn_879_jpg.rf.6ba72002872db6a44cf77f066e08cd5e.jpg
# ✅ Ground Truth: RLVBDUEM
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:14] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.20192313194274902
# [2025/02/24 20:16:14] ppocr DEBUG: cls num  : 3, elapsed : 0.025490760803222656
# [2025/02/24 20:16:15] ppocr DEBUG: rec_res num  : 3, elapsed : 0.4648442268371582
# 🖼 Image: syn_821_jpg.rf.3554ef0e1545cea0409c061e9e71c9e5.jpg
# ✅ Ground Truth: HMEM54M4L
# 🔍 OCR Result: HMEM54M4L
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:15] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.22148871421813965
# [2025/02/24 20:16:15] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:15] ppocr DEBUG: rec_res num  : 0, elapsed : 1.430511474609375e-06
# 🖼 Image: syn_780_jpg.rf.e62fc0e6c14838c325e02631cee7ef87.jpg
# ✅ Ground Truth: BL8H93K5
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:15] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.20062255859375
# [2025/02/24 20:16:15] ppocr DEBUG: cls num  : 2, elapsed : 0.014205217361450195
# [2025/02/24 20:16:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.13479042053222656
# 🖼 Image: syn_632_jpg.rf.7f604c0552fd53f8c8f71e8f3d95aa54.jpg
# ✅ Ground Truth: 6HHKU65T
# 🔍 OCR Result: 6HHKU65T
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:16] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.20374441146850586
# [2025/02/24 20:16:16] ppocr DEBUG: cls num  : 2, elapsed : 0.019827842712402344
# [2025/02/24 20:16:16] ppocr DEBUG: rec_res num  : 2, elapsed : 0.15465497970581055
# 🖼 Image: syn_54_jpg.rf.2a59fff2bb068455dc276d29d52e8f8b.jpg
# ✅ Ground Truth: FELKA1U
# 🔍 OCR Result: FELKA1U
# ⚡ WER: 0.0000
# --------------------------------------------------
# [2025/02/24 20:16:16] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.20156502723693848
# [2025/02/24 20:16:16] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:16] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# 🖼 Image: syn_703_jpg.rf.90bad0692ab8f69da9695e0a3d96b586.jpg
# ✅ Ground Truth: 5N4D51N
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
# [2025/02/24 20:16:16] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.2121567726135254
# [2025/02/24 20:16:16] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/02/24 20:16:16] ppocr DEBUG: rec_res num  : 0, elapsed : 2.1457672119140625e-06
# 🖼 Image: syn_663_jpg.rf.c17d3faefa30fe81a43fd6be4d226873.jpg
# ✅ Ground Truth: ALPS7E7Z
# 🔍 OCR Result:
# ⚡ WER: 1.0000
# --------------------------------------------------
#
# 📊 WER Moyen sur toutes les images : 0.2705
